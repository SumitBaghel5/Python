# %% [markdown]
# ## **-> Tuple**
# Ans - A tuple is a built-in data structure in Python used to store an ordered collection of items. Unlike lists, tuples are immutable, meaning once a tuple is created, its elements cannot be modified, added, or removed.
#
# **Core Characteristics**
# - Ordered: Items maintain a defined order, and that order will not change.
#
# - Immutable: Cannot be altered after creation (read-only data structure).
#
# - Allows Duplicates: Can contain identical values.
#
# - Heterogeneous: Can hold mixed data types (integers, strings, floats, lists, other tuples, etc.).
#
# - Hashable: Because they are immutable, tuples can be used as keys in dictionaries (provided all their elements are also hashable).

# %% [markdown]
# ---

# %% [markdown]
# ## **--> Creating Tuples**
# Ans - len( ) function: Determines the total number of items in a list.
#
# - tuple( ) constructor: Used to create a new list from an iterable.

# %%
# empty tuple
demo = ( )
print(demo)
print(type(demo))
print(len(demo))

print("="*30)

#  Create a tuple 
demo_2 = (5,8,2,"gaj kishor",5,0,3,96,"Rampratap",5.6)
print(demo_2)

print("="*30)

#  Length of tuple 
demo_2 = (5,8,2,"gaj kishor",5,0,3,96,"Rampratap",5.6)

print(len(demo_2))

print("="*30)

# Its called tuple packing ( paranthesis are optional)
demo_3 = 0,3,96,"Rampratap" 
print(demo_3)
print(type(demo_3))

print("="*30)

# Create Single element tuple
# [ Note - The Single-Element Trap: To create a tuple with a single item, ]
# [you must include a trailing comma. Otherwise, Python treats the parentheses as standard mathematical grouping.]

demo_4 = (5)
print(demo_4)
print(type(demo_4))

demo_5 = (6,)
print(demo_5)
print(type(demo_5))
print(len(demo_5))

print("="*30)

# Tuple Constructor

demo_6 = tuple((2,5,85,0))
print(demo_6)
print(type)
# Out:
# ()
# <class 'tuple'>
# 0
# ...
# (5, 8, 2, 'gaj kishor', 5, 0, 3, 96, 'Rampratap', 5.6)
# ...
# 10
# ...
# (0, 3, 96, 'Rampratap')
# <class 'tuple'>
# ...
# 5
# <class 'int'>
# (6,)
# <class 'tuple'>
# 1
# ...
# (2, 5, 85, 0)
# <class 'type'>

# %% [markdown]
# ---

# %% [markdown]
# ## **--> Access Tuple Items**
# Ans - You can access tuple items by referring to the index number, inside square brackets:

# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple[1])

# Negative Indexing

thistuple = ("apple", "banana", "cherry")
print(thistuple[-1])

# Range of Indexes

thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[2:5])

# Range of Negative Indexes

thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[-6:-3])

# Check if item present in ?
# Q - Check if "apple" is present in the tuple:

thistuple = ("apple","banana", "cherry", "orange", "kiwi", "melon", "mango")
if "apple" in thistuple:
    print("yes apple is present")
else:
    print("Apple is not present")
# Out:
# banana
# cherry
# ('cherry', 'orange', 'kiwi')
# ('banana', 'cherry', 'orange')
# yes apple is present

# %% [markdown]
# ---

# %% [markdown]
# ## **--> Update Tuples**
# Ans - Tuples are unchangeable, meaning that you cannot change, add, or remove items once the tuple is created.
#
# But there are some workarounds.

# %%
# Change Tuple Values 
# [ Note - It is direct not possible but first you convert a tuple into list and change its value and after convert into a list ]

tup = ("apple", "banana", "cherry")
# Changel apple in to kiwi
lis = list(tup)
print(lis)
print(type(lis))

lis[0] = "kiwi"
print(lis)

tup = tuple(lis)

print(tup)
type(tup)


#n[ Note - you perform all list function on tuple by convert tuple into list first and do changes and after convert list into a tuple]
# Out:
# ['apple', 'banana', 'cherry']
# <class 'list'>
# ['kiwi', 'banana', 'cherry']
# ('kiwi', 'banana', 'cherry')
# tuple

# %% [markdown]
# ---

# %% [markdown]
# ## **-->Loop in Tuple**

# %%
t = ("Apple", "Banana", "Mango")

for item in t:
    print(item)

print("="*23)

t = ("Apple", "Banana", "Mango")

for i in range(len(t)):
    print(i, t[i])

t=(5,15,25)
sum=0
for val in t:
    sum += val 
print("Sum:",sum)
# Out:
# Apple
# Banana
# Mango
# ...
# 0 Apple
# 1 Banana
# 2 Mango
# Sum: 45

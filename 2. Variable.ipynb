# %%
b = 52
c = 35
print (b+c)
# Out:
# 87

# %%
print (id(b))
print(type(b))
# Out:
# 140735585540824
# <class 'int'>

# %%
a = int(input("Diameter of circlr"))
r = a/2
ar = r**2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a = int(input("Diameter of circlr"))
#       2 r = a/2
#       3 ar = r**2
#
# ValueError: invalid literal for int() with base 10: ''

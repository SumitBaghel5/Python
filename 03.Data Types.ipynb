# %% [markdown]
# ### **Q-Data Types**
# Ans - Data types are used to store different types of data in variables so Python can perform different operations.
#
# -  Data types are categories that tell Python what kind of value a variable holds.

# %% [markdown]
# ### **--->Types of Data Types**
# Ans - Two types of data tyoes.
# 1. **Built-in Data Types**  -  These Data Types already available in Python.
# 2. **User-defined Data Types**  -  They are created by users using classes.

# %% [markdown]
# ---

# %% [markdown]
# ### **---> Built-in Data Types**
# | Category | Data Types |
# | :--- | :--- |
# | **Text Type** | str |
# | **Numeric Types** | int, float, complex |
# | **Sequence Types** | list, tuple, range |
# | **Mapping Type** | dict |
# | **Set Types** | set, frozenset |
# | **Boolean Type** | bool |
# | **None Type** | NoneType |

# %% [markdown]
# ---

# %% [markdown]
# ### **Q - String**
# Ans - String is a data type used to store text data.
#
# **Rules** - Anything written inside quotes (" " or ' ') is considered a string.
#
# **A string can contain**
# - Alphabets = A to Z or a to z
# - Numbers = 0 to 9
# - Symbol  = @,#,$,& etc
# - Spaces = Hi    Sumit ___

# %%
name = "Hello my name is Sumit Baghel."
print(name)
# Out:
# Hello my name is Sumit Baghel.

# %% [markdown]
# ---

# %% [markdown]
# ### **Q - Integer**
# Ans - Integer is a data type used to store numeric data.
# - It contains positive or negative whole numbers (without fractions or decimals).

# %%
a = 25
b = 36
print(a+b)
print(type(a+b))
# Out:
# 61
# <class 'int'>

# %% [markdown]
# ---

# %% [markdown]
# ### **Q - Float**
# Ans - Float is a data type used to store decimal numbers.
# - It represents real numbers with floating-point representation.
# - It is specified by a decimal point.

# %%
a = 253.3
b = 25
print(a-b)
print(type(a-b))
# Out:
# 228.3
# <class 'float'>

# %% [markdown]
# ---

# %% [markdown]
# ### **Q - Complex**
# Ans - Complex is data type used to store complex number.
# - It stores numbers with real and imaginary parts.
# - In Python, imaginary numbers are represented using j.

# %%
a = 3+4j
print(a)
print(type(a))
# Out:
# (3+4j)
# <class 'complex'>

# %% [markdown]
# ---

# %% [markdown]
# ### **Q - Boolean**
# Ans - Boolean is data type used to store True & False .
# - It is mainly used in conditions and comparisons.
# - In Python, Boolean values are represented by the bool class.

# %%
a = 25
b = 36
c = a>b
print(c)
print(type(c))
# Out:
# False
# <class 'bool'>

# %% [markdown]
# ---

# %% [markdown]
# ### **Q - None**
# Ans - None is a special value in Python used to represent no value or absence of a value.
# - It is used to represent no value / null.
# - The data type of None is NoneType.

# %%
a = "None562"
print(a)
print(type(a))
# Out:
# None562
# <class 'str'>

# %% [markdown]
# ---

# %% [markdown]
# ### **Q - List**
# Ans - List is a collection of different types of data types.
# - Element of list are seprated by comma (,) and all element are enclosed within square brackets ([ ]).
# - you listed a list in a list also.
# - Lists are mutuble can be modifed after creation.
# - You Add a Tuple inside a List.

# %%
# Example -1
list = [23.5,86,"ram",[-56,26],["apple","banana"]]
print(list)
# Out:
# [23.5, 86, 'ram', [-56, 26], ['apple', 'banana']]

# %%
# Example - 2 ( change a list)
list = [23.5,86,"ram",[-56,26],["apple","banana"]]
list[1] = 100
print(list)
# Out:
# [23.5, 100, 'ram', [-56, 26], ['apple', 'banana']]

# %%
# Example - 3 ( Tuple in list)
list = [1, 2, ["Ram", "Sam"], (5, 6)]
print(list)
# Out:
# [1, 2, ['Ram', 'Sam'], (5, 6)]

# %% [markdown]
# ---

# %% [markdown]
# ### **Q - Tuple**
# Ans - A tuple is a collection of different types of data.
#
# * Elements of a tuple are separated by commas (,) and all elements are enclosed within parentheses ( ( ) ).
# * You can also nest a tuple inside another tuple.
# * Tuples are immutable, meaning they cannot be modified after creation.
# * You Add a List inside a Tuple.

# %%
# Example -1 
tuple = (23.5,86,"ram",(-56,26),("apple","banana"))
print(tuple)
# Out:
# (23.5, 86, 'ram', (-56, 26), ('apple', 'banana'))

# %%
# Example - 2 ( change a Tuple- Show Error)
tuple = (23.5,86,"ram",(-56,26),("apple","banana"))
tuple(1) = 100
print(tuple)
# Out:
#   Cell In[5], line 3
#     tuple(1) = 100
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
# Example - 3 ( list in tuple and change it these list)
tuple = (23.5,86,"ram",[-56,26],("apple","banana"))
tuple [3][0] = -526
print(tuple)
# Out:
# (23.5, 86, 'ram', [-526, 26], ('apple', 'banana'))

# %% [markdown]
# ---

# %% [markdown]
# ### **Q - Range**
# Ans - The range data type represents an immutable sequence of numbers, commonly used for looping a specific number of times in for loops.
# - It follows the syntax: range(start, stop, step).
# - Start: The beginning of the sequence (default is 0).
# - Stop: The sequence ends before reaching this number (exclusive).
# - Step: The difference between each number in the sequence (default is 1).
# - The range type is immutable (you cannot change the numbers inside the sequence).

# %%
numbers = range(1, 10, 2)

print(type(numbers))  
print(list(numbers))
# Out:
# <class 'range'>
# [1, 3, 5, 7, 9]

# %% [markdown]
# ---

# %% [markdown]
# ### **Q - Dictionary**
# Ans - A dictionary is an ordered collection of data that stores items in key:value pairs.
# - Key-value pairs are enclosed within curly brackets { }.
# - Each pair is separated by a comma (,), and the key is separated from its value by a colon (:).
# - Keys must be unique, whereas values can be repeated.
# - Dictionaries are mutable, allowing you to modify them after they are created.

# %%
my_dict = {
    "name": "Ram",
    "age": 25,
    "city": "Delhi"
}


print(my_dict["name"],"\n",my_dict["age"])
# Out:
# Ram
#  25

# %% [markdown]
# ---

# %% [markdown]
# ### **Q - Set**
# Ans - A set is an unordered collection of unique elements.
# - The elements do not have a defined order.
# - Sets do not allow duplicate values.
# - A set is mutable. Can be modified using methods like .add() or .remove().
# - A set in a {}.

# %%
a_z = {"apple",52,"ram","ram",52}
print(a_z)
print(type(a_z))
# Out:
# {'apple', 52, 'ram'}
# <class 'set'>

# %% [markdown]
# ---

# %% [markdown]
# ### **Q - Frozenset**
# Ans - A frozenset is an unordered collection of unique elements.
# - The elements do not have a defined order.
# - Sets do not allow duplicate values.
# - A set is immutable. Can't be modified after creation.
# - A frozenset is created using frozenset() function.
# **Note** - It is similar to set but it is immutable only.

# %%
fs = frozenset([1,2,3])

fs.add(4)
print(fs)   # Error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 3
#       1 fs = frozenset([1,2,3])
#       2
# ----> 3 fs.add(4)
#       4 print(fs)   # Error
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %% [markdown]
# ---

# %% [markdown]
# ### **Q - Type conversion**
# Ans - Type conversion is the process of converting one data type into another data type.
#
# **--->There are two types**

# %% [markdown]
# ### **1. Implicit Type Conversion (Automatic)**
# - Conversion done automatically by Python.
# - Python converts smaller data types into larger compatible data types to avoid data loss.

# %%
a = 5
b = 3.0

print(a + b)
print(type(a + b))
# Out:
# 8.0
# <class 'float'>

# %% [markdown]
# ### **2.Explicit Type Conversion (Type Casting)**
# - Conversion done manually by the programmer using functions like int(), float(), str(), etc.

# %%
a = "10"

print(int(a))
print(type(a))
print(type(int(a)))
# Out:
# 10
# <class 'str'>
# <class 'int'>

# %% [markdown]
# ---

# %% [markdown]
# ### **---><u> Data Types Practice Problems </u>**

# %% [markdown]
# Q - Create an integer variable and print its datatype.

# %%
num = 52
print(type(num))
# Out:
# <class 'int'>

# %% [markdown]
# ---

# %% [markdown]
# Q - Create a float variable and print its datatype.

# %%
num_dec = 25.6
print(type(num_dec))
# Out:
# <class 'float'>

# %% [markdown]
# ---

# %% [markdown]
# Q - Add an integer and float together and print result datatype.

# %%
num_1 = 25
num_2 = 65.23

print(num_1+num_2)

print("num_1 =",type(num_1))
print("num_2 =",type(num_2))
print("num_1+num_2 =",type(num_1+num_2))
# Out:
# 90.23
# num_1 = <class 'int'>
# num_2 = <class 'float'>
# num_1+num_2 = <class 'float'>

# %% [markdown]
# ---

# %% [markdown]
# Q - Convert an integer into float.

# %%
num = 25
print(type(num))
print(type(float(25)))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# ---

# %% [markdown]
# Q - Take two numbers and print their sum.

# %%
num_1 = int(input("num_1="))
num_2 = float(input("num_2"))
print("Sum =",num_1+num_2)
# Out:
# Sum = 28.6

# %% [markdown]
# ---

# %% [markdown]
# Q - Find square of an integer.

# %%
num_1 = int(input("num_1"))
print("Square of num_1 =",num_1**2)
# Out:
# Square of num_1 = 3136

# %% [markdown]
# ---

# %% [markdown]
# Q - Print length of a string.

# %%
a = "ramcharan sing rajput"
print(len(a))
# Out:
# 21

# %% [markdown]
# ---

# %% [markdown]
# Q - Convert string into uppercase.

# %%
a = "hello my python"
print(a.upper())
# Out:
# HELLO MY PYTHON

# %% [markdown]
# ---

# %% [markdown]
# Q - Convert string into lowercase.

# %%
A = "HELLO MY PYTHON"
print(A.lower())
# Out:
# hello my python

# %% [markdown]
# ---

# %% [markdown]
# Q - Convert in to proper Text.

# %%
A = "HeLLO My PYthON"
print(A.title())
# Out:
# Hello My Python

# %% [markdown]
# ---

# %% [markdown]
# Q - Convert in to first word is capital only.

# %%
A = "HELLO my PYthON"

print(A.capitalize())
# Out:
# Hello my python

# %% [markdown]
# ---

# %% [markdown]
# Q - Print first character of string.

# %%
a = "Hi My Love Python"
print(a[0])
# Out:
# H

# %% [markdown]
# ---

# %% [markdown]
# Q - Print last character.

# %%
a = "Hi My Love Python"
print(a[-1])
# Out:
# n

# %% [markdown]
# ---

# %% [markdown]
# Q - Reverse a string.

# %%
a = "Hi My Love Python"
print(a[::-1])
# Out:
# nohtyP evoL yM iH

# %%
a = "Hi My Love Python"
word = a.split()
revers = word[::-1]
result = " ".join(revers)
print(result)
# Out:
# Python Love My Hi

# %% [markdown]
# ---
